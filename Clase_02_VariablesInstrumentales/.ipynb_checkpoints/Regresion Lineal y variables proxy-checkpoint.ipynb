# %% [markdown]
# ### REGRESIÓN LINEAL EN PYTHON Y VARIABLES PROXY

# %% [markdown]
# ##### Para esta clase utilizaremos como referencia la hipótesis y datos utilizados en el artículo: **"The Colonial Origins of Comparative Development: An Empirical Investigation"**
#
# * Autores: Daron Acemoglu, Simon Johnson, James A. Robinson
#
# * Fuente: The American Economic Review, Vol. 91, No. 5 (Dec., 2001), pp. 1369-1401 https://economics.mit.edu/files/4123
#
# * La versión en español la pueden encontrar en  redalyc.org/pdf/419/41901302.pdf

# %% [markdown]
# #### PROPÓSITO DE ESTA CLASE
# * Aplicar el concepto de variables instrumentales que ya revisamos de forma teórica.
# * Utilizando un modelo de 2 etapas analizar la hipótesis de los autores:el desempeño económico observado puede ser atribuido a las diferencias institucionales.
#
# * **Los autores del artículo proponen 3 premisas:**
#
# 1. Los diversos tipos de políticas de colonización crearon diferentes grupos de instituciones.  En un extremo, los europeos establecieron “Estados extractivos” , instituciones que  no proporcionaron mucha protección a la propiedad privada, ni establecieron un sistema de pesos y contrapesos contra la  expropiación del gobierno.
#
# * En el otro extremo, muchos europeos emigraron y se asentaron en diversas colonias, creando  “nuevas Europas”. Los colonizadores trataron de replicar las instituciones europeas, con gran énfasis en la propiedad privada y en el control del poder del gobierno.
#
# 2. La factibilidad de los asentamientos influyó en la estrategia de colonización. En lugares donde el ambiente insalubre no era favorable al asentamiento europeo, no resultaba posible crear “nuevas Europas”,y era más factible la formación del Estado extractivo.
#
# 3. El Estado colonial y las instituciones persistieron aun después de la independencia.
#
#
# * **HIPÓTESIS:** las tasas de mortalidad (potenciales) de los colonizadores fueron el principal determinante de los asentamientos; los asentamientos fueron un determinante importante de las instituciones iniciales (en la práctica, las instituciones de 1900); y existe una fuerte correlación entre las instituciones iniciales y las instituciones actuales.
#
# **¿Cómo medimos las diferencias institucionales y los resultados económicos?**
#
# * Los resultados económicos de una economía son aproximados por el logaritmo del PIB per cápita en 1995, ajustados por la paridad del poder adquisitivo, ppp.
#
# * Las diferencias institucionales son aproximadas mediante el  índice de protección contra la expropiación que reporta un  valor entre 0 y 10 para cada país y año,donde 0 corresponde a la menor protección contra la expropiación. Se utilizó  el valor promedio de cada país entre 1985 y 1995 ( “riesgo de expropiación” promedio 1985-95", este índice fue construido por el Grupo de Servicios de Riesgo Político https://www.prsgroup.com/).
#
# * La principal contribución del artículo es el uso de las tasas de mortalidad como fuente de variación exógena en las diferencias institucionales.
#
# * Dicha variación es necesaria para determinar si son las instituciones las que dan lugar a un mayor crecimiento económico, y no al revés.

# %% [markdown]
# ### 1.- Importando las librerías necesarias
# * Para esta clase necesitamos instalar linearmodels

# %%
# !git clone https://github.com/bashtage/linearmodels
# !cd linearmodels
# !pip install --upgrade setuptools>
# !python setup.py install
# Out:
# fatal: destination path 'linearmodels' already exists and is not an empty directory.
# /bin/sh: -c: line 0: syntax error near unexpected token `newline'
# /bin/sh: -c: line 0: `pip install --upgrade setuptools>'
# python: can't open file 'setup.py': [Errno 2] No such file or directory

# %%
#!pip install linearmodels==1.0
#conda install -c conda-forge linearmodels

# %%
# !pip install -U pandas
# !pip install -U pandas_summary
# !pip install git+https://github.com/pydata/pandas-datareader
# Out:
# Requirement already up-to-date: pandas in /Applications/anaconda/envs/PythonData/lib/python3.7/site-packages (1.0.3)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.6.1 in /Applications/anaconda/envs/PythonData/lib/python3.7/site-packages (from pandas) (2.8.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in /Applications/anaconda/envs/PythonData/lib/python3.7/site-packages (from pandas) (1.17.4)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /Applications/anaconda/envs/PythonData/lib/python3.7/site-packages (from pandas) (2019.3)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /Applications/anaconda/envs/PythonData/lib/python3.7/site-packages (from python-dateutil>=2.6.1->pandas) (1.13.0)
# Requirement already up-to-date: pandas_summary in /Applications/anaconda/envs/PythonData/lib/python3.7/site-packages (0.0.7)
# Requirement already satisfied, skipping upgrade: numpy in /Applications/anaconda/envs/PythonData/lib/python3.7/site-packages (from pandas_summary) (1.17.4)
# Requirement already satisfied, skipping upgrade: pandas in /Applications/anaconda/envs/PythonData/lib/python3.7/site-packages (from pandas_summary) (1.0.3)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.6.1 in /Applications/anaconda/envs/PythonData/lib/python3.7/site-packages (from pandas->pandas_summary) (2.8.1)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /Applications/anaconda/envs/PythonData/lib/python3.7/site-packages (from pandas->pandas_summary) (2019.3)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /Applications/anaconda/envs/PythonData/lib/python3.7/site-packages (from python-dateutil>=2.6.1->pandas->pandas_summary) (1.13.0)
# Collecting git+https://github.com/pydata/pandas-datareader
#   Cloning https://github.com/pydata/pandas-datareader to /private/var/folders/6r/13w7jly523j124vf77383l4m0000gn/T/pip-req-build-l5i2ebk4
#   Running command git clone -q https://github.com/pydata/pandas-datareader /private/var/folders/6r/13w7jly523j124vf77383l4m0000gn/T/pip-req-build-l5i2ebk4
# Requirement already satisfied (use --upgrade to upgrade): pandas-datareader==0.9.0.dev0+35.gc60ea8a from git+https://github.com/pydata/pandas-datareader in /Applications/anaconda/envs/PythonData/lib/python3.7/site-packages
# Requirement already satisfied: lxml in /Applications/anaconda/envs/PythonData/lib/python3.7/site-packages (from pandas-datareader==0.9.0.dev0+35.gc60ea8a) (4.4.2)
# Requirement already satisfied: pandas>=0.21 in /Applications/anaconda/envs/PythonData/lib/python3.7/site-packages (from pandas-datareader==0.9.0.dev0+35.gc60ea8a) (1.0.3)
# Requirement already satisfied: requests>=2.3.0 in /Applications/anaconda/envs/PythonData/lib/python3.7/site-packages (from pandas-datareader==0.9.0.dev0+35.gc60ea8a) (2.22.0)
# Requirement already satisfied: pytz>=2017.2 in /Applications/anaconda/envs/PythonData/lib/python3.7/site-packages (from pandas>=0.21->pandas-datareader==0.9.0.dev0+35.gc60ea8a) (2019.3)
# Requirement already satisfied: python-dateutil>=2.6.1 in /Applications/anaconda/envs/PythonData/lib/python3.7/site-packages (from pandas>=0.21->pandas-datareader==0.9.0.dev0+35.gc60ea8a) (2.8.1)
# Requirement already satisfied: numpy>=1.13.3 in /Applications/anaconda/envs/PythonData/lib/python3.7/site-packages (from pandas>=0.21->pandas-datareader==0.9.0.dev0+35.gc60ea8a) (1.17.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /Applications/anaconda/envs/PythonData/lib/python3.7/site-packages (from requests>=2.3.0->pandas-datareader==0.9.0.dev0+35.gc60ea8a) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Applications/anaconda/envs/PythonData/lib/python3.7/site-packages (from requests>=2.3.0->pandas-datareader==0.9.0.dev0+35.gc60ea8a) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Applications/anaconda/envs/PythonData/lib/python3.7/site-packages (from requests>=2.3.0->pandas-datareader==0.9.0.dev0+35.gc60ea8a) (2019.11.28)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Applications/anaconda/envs/PythonData/lib/python3.7/site-packages (from requests>=2.3.0->pandas-datareader==0.9.0.dev0+35.gc60ea8a) (1.25.7)
# Requirement already satisfied: six>=1.5 in /Applications/anaconda/envs/PythonData/lib/python3.7/site-packages (from python-dateutil>=2.6.1->pandas>=0.21->pandas-datareader==0.9.0.dev0+35.gc60ea8a) (1.13.0)
# Building wheels for collected packages: pandas-datareader
#   Building wheel for pandas-datareader (setup.py) ... done
#   Created wheel for pandas-datareader: filename=pandas_datareader-0.9.0.dev0+35.gc60ea8a-py2.py3-none-any.whl size=107811 sha256=64bcee32208df9a5cbba05427eeb2e8a23c4dbfec6667cf552f2671f9d290144
#   Stored in directory: /private/var/folders/6r/13w7jly523j124vf77383l4m0000gn/T/pip-ephem-wheel-cache-lps_9o9k/wheels/59/93/2c/e02bc7f2d3edcb5c462616dbdb0beb0bc0cc37410fffd184a0
# Successfully built pandas-datareader

# %%
import numpy as np
import pandas as pd
pd.core.common.is_list_like = pd.api.types.is_list_like
import matplotlib.pyplot as plt
# %matplotlib inline
import statsmodels.api as sm
from statsmodels.iolib.summary2 import summary_col
from linearmodels.iv import IV2SLS
from linearmodels.iv import IVLIML
#from linearmodels import IV2SLS, IVLIML, IVGMM, IVGMMCUE
# Out:
# /Applications/anaconda/envs/PythonData/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-4200dadbbea3> in <module>
#       8 from linearmodels.iv import IV2SLS
#       9 from linearmodels.iv import IVLIML
# ---> 10 from linearmodels import IV2SLS, IVLIML, IVGMM, IVGMMCUE
#
# ImportError: cannot import name 'IV2SLS' from 'linearmodels' (/Applications/anaconda/envs/PythonData/lib/python3.7/site-packages/linearmodels/__init__.py)

# %% [markdown]
# ### 2.-Descargando los datos.
# * Con la ayuda de la instrucción *read_stata* leeremos los datos, nuestro Dataframe contiene la siguiente información:
# - shortnam - Abreviatura Nonmbre país.
# - euro1900 -Restricciones al Ejecutivo en 1900
# - excolony: variable dummy 1- excolonia -0 no excolonia
# - logpgp95 logaritmo del pib per cápita en 1995
# - avexpr
#   logaritmo de la tasa de mortalidad de los colonizadores para una muestra de 75 países,
# - cons1 Constraint on executive in first year of independence
# -cons90 Constraint on executive in 1900
# -democ00a ïndice de democracia 1900
# -cons00a
# -extmort4
# -logem4	Logaritmo del pib por trabajador, 1988
# -loghjypl
# -baseco

# %%
import pandas as pd
df1 = pd.read_stata('maketable1.dta')
df1.head()
# Out:
#   shortnam   euro1900  excolony    avexpr  logpgp95  cons1  cons90  democ00a  \
# 0      AFG   0.000000       1.0       NaN       NaN    1.0     2.0       1.0
# 1      AGO   8.000000       1.0  5.363636  7.770645    3.0     3.0       0.0
# 2      ARE   0.000000       1.0  7.181818  9.804219    NaN     NaN       NaN
# 3      ARG  60.000004       1.0  6.386364  9.133459    1.0     6.0       3.0
# 4      ARM   0.000000       0.0       NaN  7.682482    NaN     NaN       NaN
#
#    cons00a    extmort4    logem4  loghjypl  baseco
# 0      1.0   93.699997  4.540098       NaN     NaN
# 1      1.0  280.000000  5.634789 -3.411248     1.0
# 2      NaN         NaN       NaN       NaN     NaN
# 3      3.0   68.900002  4.232656 -0.872274     1.0
# 4      NaN         NaN       NaN       NaN     NaN

# %% [markdown]
# ### 3.- Explorando los datos de forma gráfica
# * Con una gráfica de dispersión exploraremos la relación entre las variables **'avexpr' Protección promedio contra el riesgo de expropiación,1985-1995 y 'logpgp95' Logaritmo del pib per cápita, 1975 y 1995**.
# * ¿Qué tipo de relación observas en los datos?

# %%
plt.style.use('seaborn')
df1.plot(x='avexpr', y='logpgp95', kind='scatter')
plt.title('Gráfica 1:Gráfico de dispersión')
plt.show()

# %% [markdown]
# ### 4.- Modelo OLS Bivariado
#
# * Si un alto índice de  Protección promedio contra el riesgo de expropiación es una medida de calidad institucional, entonces **"mejores instituciones"  parecen estar positivamente correlacionadas con mejores desempeño económico (medido como un alto PIB per capita).**
#
# * Para describir esta relación, podríamos generar un **modelo bivariado entre el PIB percápita como variable dependiente y el Índice de Protección  promedio contra el riesgo de expropiación  como variable explicativa.**

# %%
# Generamos un subconjunto limpio de datos eliminando las observaciones con datos NA
df1_subset = df1.dropna(subset=['logpgp95', 'avexpr'])

df1_subset = df1_subset[df1_subset['baseco'] == 1]
#Establecemos los parámetros X y Y
X = df1_subset['avexpr']
y = df1_subset['logpgp95']
#Guardamos los valores de nuestras etiquetas 
labels = df1_subset['shortnam']

# Reemplazamos los marcadores con los nombres de las etiquetas
fig, ax = plt.subplots()
ax.scatter(X, y, marker='')

for i, label in enumerate(labels):
    ax.annotate(label, (X.iloc[i], y.iloc[i]))

# Trazamos una línea de tendencia
ax.plot(np.unique(X),
         np.poly1d(np.polyfit(X, y, 1))(np.unique(X)),
         color='black')

ax.set_xlim([3.3,10.5])
ax.set_ylim([4,10.5])
ax.set_xlabel('Protección promedio contra el riesgo de expropiación 1985-95')
ax.set_ylabel('Log PIB per capita, PPP, 1995')
ax.set_title('Gráfica 2: OLS relación entre riesgo de expropiación e ingreso')
plt.show()

# %% [markdown]
# * Para estimar los parámetros del modelo OLS, necesitamos añadir una columna con valor 1

# %%
df1['const'] = 1

# %% [markdown]
# * Ahora podemos construir el modelo OLS

# %%
reg1 = sm.OLS(endog=df1['logpgp95'], exog=df1[['const', 'avexpr']], \
    missing='drop')
type(reg1)
# Out:
# statsmodels.regression.linear_model.OLS

# %% [markdown]
# * Para estimar los parámetros del intercpeto y B1 utilizamos la instrucción **.fit()**

# %%
results = reg1.fit()
type(results)
# Out:
# statsmodels.regression.linear_model.RegressionResultsWrapper

# %% [markdown]
# * Utilizaremos el método .summary() para ver el resumen de resultados

# %%
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               logpgp95   R-squared:                       0.611
# Model:                            OLS   Adj. R-squared:                  0.608
# Method:                 Least Squares   F-statistic:                     171.4
# Date:                Sun, 12 Apr 2020   Prob (F-statistic):           4.16e-24
# Time:                        23:51:17   Log-Likelihood:                -119.71
# No. Observations:                 111   AIC:                             243.4
# Df Residuals:                     109   BIC:                             248.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.6261      0.301     15.391      0.000       4.030       5.222
# avexpr         0.5319      0.041     13.093      0.000       0.451       0.612
# ==============================================================================
# Omnibus:                        9.251   Durbin-Watson:                   1.689
# Prob(Omnibus):                  0.010   Jarque-Bera (JB):                9.170
# Skew:                          -0.680   Prob(JB):                       0.0102
# Kurtosis:                       3.362   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Resultados:
# **intercepto=4.63, B1=0.53,** la calidad institucional tiene un efecto positivo  en el desempeño económico.
# **p-value:** El efecto de las instituciones sobre el PIB per cápita  es estadísticamente significativo
# **R²=.611** al rededor de 61% de la variación en la variable LOG PIB per cápita es explicada por la variable Índice de  Protección promedio contra el riesgo de expropiación

# %% [markdown]
# ### Utilizando nuestro modelo para predecir niveles de PIB per cápita

# %%
#primero calculamos el promedio de avexpr
mean_expr = np.mean(df1_subset['avexpr'])
mean_expr
results.predict(exog=[1, mean_expr])
# Out:
# array([8.09156367])

# %% [markdown]
# ### Podemos obtener el valor predicho para cada valor del Índice de  Protección promedio contra el riesgo de expropiación

# %%
# Eliminamos los valores perdidos de la base

df1_plot = df1.dropna(subset=['logpgp95', 'avexpr'])

# Graficamos los valores predichos

fix, ax = plt.subplots()
ax.scatter(df1_plot['avexpr'], results.predict(), alpha=0.5,
        label='Predicho')

# Graficamos los valores observados

ax.scatter(df1_plot['avexpr'], df1_plot['logpgp95'], alpha=0.5,
        label='Observado')

ax.legend()
ax.set_title('OLS valores predichos')
ax.set_xlabel('avexpr')
ax.set_ylabel('logpgp95')
plt.show()

# %% [markdown]
# ###  5.-Modelo Multivariado
# * Hasta ahora, nuestro modelo sólo considera como variable explicativa el Índice de  Protección promedio contra el riesgo de expropiación, seguramente existen otras variables que tienen un efecto sobre el PIB per cápita.
#
# * Los cálculos de los parámetros de nuestro modelo pueden estar afectados por lo que se conoce como **"sesgo de variable omitida"**, para solucionar este problema, extenderemos nuestro modelo para incluir otras variables.

# %%
#descargamos los datos para nuestro modelo multivariado

df2 = pd.read_stata('maketable2.dta')

# Creamos nuestra constante
df2['const'] = 1

# Creamos una lista de variables que serán utilizadas en cada regresión (vamos a generar 3 modelos) 
X1 = ['const', 'avexpr']
X2 = ['const', 'avexpr', 'lat_abst']
X3 = ['const', 'avexpr', 'lat_abst', 'asia', 'africa', 'other']

# Estimaremos un modelo de regresión OLS por cada conjunto de variables.
reg1 = sm.OLS(df2['logpgp95'], df2[X1], missing='drop').fit()
reg2 = sm.OLS(df2['logpgp95'], df2[X2], missing='drop').fit()
reg3 = sm.OLS(df2['logpgp95'], df2[X3], missing='drop').fit()

# %% [markdown]
# * Con la instrucción **summary_col** vamos a desplegar los resultados de los tres modelos en una sola tabla

# %%
info_dict={'R-squared' : lambda x: f"{x.rsquared:.2f}",
           'No. observations' : lambda x: f"{int(x.nobs):d}"}

results_table = summary_col(results=[reg1,reg2,reg3],
                            float_format='%0.2f',
                            stars = True,
                            model_names=['Model 1',
                                         'Model 3',
                                         'Model 4'],
                            info_dict=info_dict,
                            regressor_order=['const',
                                             'avexpr',
                                             'lat_abst',
                                             'asia',
                                             'africa'])

results_table.add_title('Table 2 - OLS Regressions')

print(results_table)
# Out:
#         Table 2 - OLS Regressions
# =========================================
#                  Model 1 Model 3 Model 4
# -----------------------------------------
# const            4.63*** 4.87*** 5.85***
#                  (0.30)  (0.33)  (0.34)
# avexpr           0.53*** 0.46*** 0.39***
#                  (0.04)  (0.06)  (0.05)
# lat_abst                 0.87*   0.33
#                          (0.49)  (0.45)
# asia                             -0.15
#                                  (0.15)
# africa                           -0.92***
#                                  (0.17)
# other                            0.30
#                                  (0.37)
# R-squared        0.61    0.62    0.72
# No. observations 111     111     111
# =========================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01

# %% [markdown]
# ### Endogeneidad Modelo de Mínimos Cuadrados en dos etapas
# * **Endogeneidad** puede surgir como resultado de un error de medición, autorregresión con autocorrelación de errores, simultaneidad y variables omitidas. Utilizando un modelo OLS de dos etapas revisaremos cómo podemos arreglar este problema.
#
# * La relación que existe entre el Índice de protección  promedio contra el riesgo de expropiación ('avexpr') y el    Logaritmo del PIB per cápita, puede ser bidireccional.
# * Por ejemplo, es probable que los países más ricos puedan financiar o preferir mejores instituciones; o que las variables que afectan el ingreso también pueden estar correlacionadas con diferencias institucionales; también podría se plausible que  la construcción del índice de protección  promedio contra el riesgo de expropiación pudo sesgarse,  los analistas pueden estar predispuestos a ver que los países con mayores ingresos tengan mejores instituciones

# %% [markdown]
# #### Desarrollo del modelo OLS en dos etapas:
# * Para eliminar la endogeneidad utilizaremos el OLS en dos etapas.
#
# * **El método requiere reemplazar la variable "endógena"; en este caso 'avexpr' con una variable que 1) este correlacionada con la variable éndogena 'avexpr'** y **2)No está correlacionada con el término de error (por ejemplo  no debe afectar directamente a la variable dependiente (y)**
#
#
# *  En su artículo Acemoglu, Johnson y Robinson utilizan como variable instrumental la tasa de mortalidad de los colonizadores para instrumentar las diferencias institucionales.
#
#
# * La hipótesis de los autores es que altas tasas de mortalidad de los colonizadores condujeron al establecimiento de instituciones más extractivas(menores índice de protección  promedio contra el riesgo de expropiación).
#
#
# * Veamos gráficamente la relación entre el índice de protección  promedio contra el riesgo de expropiación ('avexpr') y el logartitmo de la tasas de mortalidad de los colonizadores 'logem4'.

# %%
# Eliminar todos los valores pedrdidos
df1_subset2 = df1.dropna(subset=['logem4', 'avexpr'])

X = df1_subset2['logem4']
y = df1_subset2['avexpr']
labels = df1_subset2['shortnam']

#Asignamos las etiquetas
fig, ax = plt.subplots()
ax.scatter(X, y, marker='')

for i, label in enumerate(labels):
    ax.annotate(label, (X.iloc[i], y.iloc[i]))

# Ajustamos la linea de tendencia
ax.plot(np.unique(X),
         np.poly1d(np.polyfit(X, y, 1))(np.unique(X)),
         color='black')

ax.set_xlim([1.8,8.4])
ax.set_ylim([3.3,10.4])
ax.set_xlabel('Logartitmo de la tasas de mortalidad de los colonizadores')
ax.set_ylabel('Promedio de Riesgo de Expropiación 1985-95')
ax.set_title('Gráfica 3: Primera etapa relación entre tasa de mortalidad de los colonizadores y riesgo de expropiación')
plt.show()

# %% [markdown]
# **Como se observa en la Gráfica 3 el Índice de protección contra la expropiación se correlaciona negativamente con las tasas de mortalidad de los colonizadores,satisfaciendo la primera condición de un instrumento válido**

# %% [markdown]
# ### Etapa 1 Modelo OLS
#
# * La primera etapa requiere calcular la regresión entre el índice de protección  promedio contra el riesgo de expropiación ('avexpr') y las variables exógenas en nuestro modelo, en este caso el 'Logartitmo de la tasas de mortalidad de los colonizadores (variable instrumental)

# %%
# Leyendo los datos
df4 = pd.read_stata('maketable4.dta')
df4 = df4[df4['baseco'] == 1]

# Añadir la constante
df4['const'] = 1

# Regresión 1a Etapa 
results_fs = sm.OLS(df4['avexpr'],
                    df4[['const', 'logem4']],
                    missing='drop').fit()
print(results_fs.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 avexpr   R-squared:                       0.270
# Model:                            OLS   Adj. R-squared:                  0.258
# Method:                 Least Squares   F-statistic:                     22.95
# Date:                Sun, 12 Apr 2020   Prob (F-statistic):           1.08e-05
# Time:                        23:51:46   Log-Likelihood:                -104.83
# No. Observations:                  64   AIC:                             213.7
# Df Residuals:                      62   BIC:                             218.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          9.3414      0.611     15.296      0.000       8.121      10.562
# logem4        -0.6068      0.127     -4.790      0.000      -0.860      -0.354
# ==============================================================================
# Omnibus:                        0.035   Durbin-Watson:                   2.003
# Prob(Omnibus):                  0.983   Jarque-Bera (JB):                0.172
# Skew:                           0.045   Prob(JB):                        0.918
# Kurtosis:                       2.763   Cond. No.                         19.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Etapa 2
# * Para calcular la segunda etapa necesitamos recuperar los valores pronosticados por el modelo para el índice de protección  promedio contra el riesgo de expropiación ('avexpr'). Utilizamos el comando **.predict()**
# * Reemplazaremos en nuestro modelo original  nuestra variable endógena por nuestros valores predichos.
# * Los resultados de la regresión de la segunda etapa nos dan una estimación imparcial y consistente del efecto de las instituciones en los resultados económicos.

# %%
df4['predicted_avexpr'] = results_fs.predict()

results_ss = sm.OLS(df4['logpgp95'],
                    df4[['const', 'predicted_avexpr']]).fit()
print(results_ss.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               logpgp95   R-squared:                       0.477
# Model:                            OLS   Adj. R-squared:                  0.469
# Method:                 Least Squares   F-statistic:                     56.60
# Date:                Sun, 12 Apr 2020   Prob (F-statistic):           2.66e-10
# Time:                        23:51:50   Log-Likelihood:                -72.268
# No. Observations:                  64   AIC:                             148.5
# Df Residuals:                      62   BIC:                             152.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                1.9097      0.823      2.320      0.024       0.264       3.555
# predicted_avexpr     0.9443      0.126      7.523      0.000       0.693       1.195
# ==============================================================================
# Omnibus:                       10.547   Durbin-Watson:                   2.137
# Prob(Omnibus):                  0.005   Jarque-Bera (JB):               11.010
# Skew:                          -0.790   Prob(JB):                      0.00407
# Kurtosis:                       4.277   Cond. No.                         58.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# * El resultado sugiere una relación positiva más fuerte que lo que indicaron los resultados del primer OLS, aunque nuestras estimaciones de parámetros son correctas, nuestros errores estándar no lo son y, por esta razón, no se recomienda calcular el modelo de dos etapas  "manualmente"
#
# * Podemos estimar correctamente una regresión 2SLS en un solo paso usando el paquete linearmodels, una extensión de statsmodels.

# %%
#from linearmodels import IV2SLS, IVLIML, IVGMM, IVGMMCUE

iv = IV2SLS(dependent=df4['logpgp95'],
            exog=df4['const'],
            endog=df4['avexpr'],
            instruments=df4['logem4']).fit(cov_type='unadjusted')

print(iv.summary)
# Out:
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:               logpgp95   R-squared:                      0.1870
# Estimator:                    IV-2SLS   Adj. R-squared:                 0.1739
# No. Observations:                  64   F-statistic:                    37.568
# Date:                Sun, Apr 12 2020   P-value (F-stat)                0.0000
# Time:                        23:52:12   Distribution:                  chi2(1)
# Cov. Estimator:            unadjusted
#
#                              Parameter Estimates
# ==============================================================================
#            Parameters  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          1.9097     1.0106     1.8897     0.0588     -0.0710      3.8903
# avexpr         0.9443     0.1541     6.1293     0.0000      0.6423      1.2462
# ==============================================================================
#
# Endogenous: avexpr
# Instruments: logem4
# Unadjusted Covariance (Homoskedastic)
# Debiased: False
